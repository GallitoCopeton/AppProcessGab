# %%
import pymongo as pymongo
import base64
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
#Only read mongodb connection
MONGO_URL = 'mongodb://findOnlyReadUser:RojutuNHqy@unimahealth.ddns.net:27017/datamap'
client = pymongo.MongoClient(MONGO_URL)

# %%
db = client.datamap

# %%
cursor_img = db.imagestotals.find_one({'fileName': "699170400100033", 'count': 2})
if(cursor_img): 
    print("One record found")
else: 
    print("No records!")
# Out:
# One record found

# %%
print(cursor_img['file'])

# %%
def readb64(base64_string):
    nparr = np.fromstring(base64.b64decode(base64_string), np.uint8)
    img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    return img

cvimg = readb64(cursor_img['file'])
cvimgRGB = cv2.cvtColor(cvimg,cv2.COLOR_BGR2RGB)
plt.subplot(121),plt.imshow(cvimgRGB)
plt.show()
