# %%
import pymongo as pymongo
import base64
import cv2
import numpy as np
import sys
from matplotlib import pyplot as plt

#Scripts para leer y procesar imagen
sys.path.insert(0, '../Golden Master (AS IS)')
import readImage

# Mongodb connection string - Does this user can write?
MONGO_URL = 'mongodb://findOnlyReadUser:RojutuNHqy@unimahealth.ddns.net:27017/datamap'

# Mongodb image collection
MONGO_COLLECTION_QR = "imagetotals"
MONGO_COLLECTION_XM = "imagexm" 

#Image folders
IMG_FOLDER = "C:/Users/LaptopUser/jupyterNotebook/Imagenes/"
XM_FOLDER = "C:/Users/LaptopUser/jupyterNotebook/Imagenes XM/" 

def writeLocal(filename, img, folder = XM_FOLDER):
    path = folder + filename
    return cv2.imwrite(path, img)

def print_im_happy():
    print("Im happy...")

print_im_happy()
# Out:
# Im happy...

# %%
qr = '601170500100157'
qr_count = 1
batch = False

# %%
#Read from local file local = True, from db local = False, count = Test repeated

#Pregunta 1: En que formato esta la imagen en MongoDB?

#Respuesta: Se asume que la imagen esta en formato RGB (Red-Green-Blue)        

imgRGB = readImage.readImage(qr, local = False, count = qr_count)
if(isinstance(imgRGB, str)):
    print(imgRGB)
else: 
    # show the original image
    if (not batch):
     plt.subplot(121),plt.imshow(imgRGB)
     plt.show()

# %%
#Hipotesis 1: la imagen resultante de la transformacion RGB a BGR es igual a la transformacion BGR a RGB
#Conclusion: Si la hipotesis 1 es cierta, no hay forma de saber que tipo de imagen es a base de transformala y mostrarla
#Por ejemplo: Estas dos imagenes se ven iguales
plt.subplot(121), plt.imshow(cv2.cvtColor(imgRGB, cv2.COLOR_BGR2RGB))
plt.subplot(122), plt.imshow(cv2.cvtColor(imgRGB, cv2.COLOR_RGB2BGR))
plt.show()

# %%
#Hipotesis 2a: El modulo imwrite de openCV guarda en modo BGR SIEMPRE
#Hipotesis 2b: imwrite convierte automaticamente de BGR a RGB, es decir, siempre hace una conversion
#            de BGR a RGB - por lo que la imagen queda en BGR, si y solo si, la imagen estaba en RGB 
#Evidencia: Despues de correr la instruccion de abajo, la imagen se ve azul en windows explorer 
#           (Asumimos que Windows explorer refleja el formato real de la imagen en Disco)
#Conclusion: Esto parece soportar la hipotesis 2b, pareciera que:
#             a) la imagen en la base de datos recibida en la funcion readImmage arriba esta en formato RGB
#             b) imwrite hace una transformacion RGB a BGR y a imagen queda en BGR en el disco(por eso se ve azul)
writeLocal("test01.png", imgRGB)
# Out:
# True

# %%
#Corolario a Hipotesis 2b: imread o matplotlib hacen otra conversion implicita RGB a BGR?
#Pregunta 2c: porque la imagen de abajo se muestra en Jupyter como RBG, cuando en explorer esta en BGR?
#Pregunta 2d: Quien esta haciendo el cambio de BGR a RGB.... imread o matplotlib?         
imgTest01 = readImage.readLocal("C:/Users/LaptopUser/jupyterNotebook/Imagenes XM/" + "test01.png")
plt.subplot(121), plt.imshow(imgTest01)
plt.show()

# %%
#Contra Ejemplo 3: Transformamos imagen de la base de datos a BGR (supuesta en RGB en la base de datos)
#Evidecia: Esta transformacion despliega azul en matplotlib
imgBGR = cv2.cvtColor(imgRGB, cv2.COLOR_BGR2RGB)
plt.imshow(imgBGR)
plt.show()

# %%
# Si guardamos esta imagen que se muestra azul en matplotlib 
# Evidencia: Esta imagen se ve RGB en windows explorer
# Posible Conclusion: Esto parece apoyar la hipotesis de que imwrite realiza siempre una transformacion
#                      Que dependiendo de que imagen sea la original puede ser de BGR a RGB o vicevesa
# Conclusion: imwrite asume que la imagen esta en BGR y siemre hace una transformacion que depende del formato
#             de la imagen de origen. Por ejemplo, de BGR a RGB o viceversa 
#             Otra forma de decirlo es que si la imagen esta en RGB la transformara a BGR y viceversa
writeLocal("test02.png", imgBGR)
# Out:
# True

# %%
#Evidencia: Al hacer la lectura de la imagen BGR y presentarla en matplotlib la imagen se ve en BGR
#Conclusion: Si asumimos que la imagen esta en BGR realmente (windows explorer refleja la realidad)
#            Entonces Matplot lib no hace ninguna conversion (el que realiza la conversion es imwrite)
imgTest02 = readImage.readLocal("C:/Users/LaptopUser/jupyterNotebook/Imagenes XM/" + "test02.png")
plt.subplot(121), plt.imshow(imgTest02)
plt.show()

# %%
#Corolary: This seems to contradict the evidence in this post
# https://stackoverflow.com/questions/29192648/opencv-cvsaveimage-saves-rgb-jpg-image-in-bgr-format
#let OpenCV work for you. You don't have to do conversions to output RGB images
#Creo que el post esta mal ya que OpenCV no tiene forma de saber cual es la imagen original
#En binario BGR y RGB se ven igual (son solo las dimensiones R y B que se intercambian)
#Esto pudiera ser una limitante de la metadata de openCV o python (que no tiene una clase que diga que tipo es)
#Por ejemplo, ver 
#https://stackoverflow.com/questions/30802493/how-can-i-know-if-the-image-is-in-rgb-or-bgr-format
